# %% [markdown]
# <a href="https://colab.research.google.com/github/UMMEATHIYA/Capacitor-Defect-Detection/blob/master/Capacitor_Defect_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QJwb0CJOTRM0pzEiXJZd")
project = rf.workspace("davi-ahilya-institure").project("capacitor-defect-identification")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 715.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Capacitor-Defect-Identification--1 in yolov8:: 100%|██████████| 80/80 [00:00<00:00, 3840.98it/s]

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QJwb0CJOTRM0pzEiXJZd")
project = rf.workspace("davi-ahilya-institure").project("capacitor-defect-identification")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.52, to fix: `pip install ultralytics==8.0.196`

# %%
pip install ultralytics==8.0.196
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.52
#     Uninstalling ultralytics-8.2.52:
#       Successfully uninstalled ultralytics-8.2.52
# ...

# %%
import yaml

with open("/content/Capacitor-Defect-Identification--1/data.yaml", "r") as file:
    data = yaml.safe_load(file)

print(data)
# Out:
# {'names': ['Burnt gasket', 'Damaged Pin', 'No Defects', 'Scruffy Gasket'], 'nc': 4, 'roboflow': {'license': 'Public Domain', 'project': 'capacitor-defect-identification', 'url': 'https://universe.roboflow.com/davi-ahilya-institure/capacitor-defect-identification/dataset/1', 'version': 1, 'workspace': 'davi-ahilya-institure'}, 'test': '../test/images', 'train': 'Capacitor-Defect-Identification--1/train/images', 'val': 'Capacitor-Defect-Identification--1/valid/images'}

# %%
# %cd /content/MyDrive/dataset
# Out:
# /content/MyDrive/dataset

# %%
# !yolo task=detect mode=train model=yolov8s.pt data = /content/MyDrive/dataset/data.yaml epochs=4 imgsz=800
# Out:
# New https://pypi.org/project/ultralytics/8.2.52 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the file path to the image
file_path = f'/content/runs/detect/train5/confusion_matrix.png'

# Load the image
img = mpimg.imread(file_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the file path to the image
file_path = f'/content/runs/detect/train5/val_batch0_pred.jpg'

# Load the image
img = mpimg.imread(file_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the file path to the image
file_path = f'/content/runs/detect/train5/val_batch0_labels.jpg'

# Load the image
img = mpimg.imread(file_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()
